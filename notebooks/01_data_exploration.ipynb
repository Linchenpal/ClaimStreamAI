# %%
import os
# move up from notebooks/ into the project root
os.chdir(os.path.dirname(os.getcwd()))
print("Working dir:", os.getcwd())
# Out:
# Working dir: /home/linam.palacios/code/Linchenpal/ClaimStreamAI

# %%
import pandas as pd

df = pd.read_csv("data/raw/insurance_claims.csv")

# Show the first 5 rows
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df = pd.read_parquet("data/raw/simulated_stream_input/claims_200k_ml.parquet")
df.head()
# Out:
#    months_as_customer        age  policy_number policy_bind_date policy_state  \
# 0          110.919593  33.428086  458021.056704       2006-09-07           OH
# 1          217.864888  42.064931  784742.986033       1997-06-18           IN
# 2          243.234109  39.370761  324347.618586       1999-04-09           IN
# 3          247.314101  43.197992  388881.850065       1996-01-23           OH
# 4          277.092351  47.161201  226808.707630       1995-08-29           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0   500/1000        1967.889465            1258.616894    4.072759e+06
# 1    250/500        2070.984715            1610.309072    0.000000e+00
# 2   500/1000        2026.884708            1193.695534    0.000000e+00
# 3    100/300        2055.485236            1188.120616    0.000000e+00
# 4   500/1000         490.771706            1151.546972    8.043732e+06
#
# ...
